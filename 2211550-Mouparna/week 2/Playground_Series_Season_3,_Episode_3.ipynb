# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/train.csv")

# %%
df.head(6)
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
# 5   5   27      Travel_Rarely        566  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
# 5                 2          3          Other              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         id  Age     BusinessTravel  DailyRate              Department  \
# 0        0   36  Travel_Frequently        599  Research & Development
# 1        1   35      Travel_Rarely        921                   Sales
# 2        2   32      Travel_Rarely        718                   Sales
# 3        3   38      Travel_Rarely       1488  Research & Development
# 4        4   50      Travel_Rarely       1017  Research & Development
# ...    ...  ...                ...        ...                     ...
# 1672  1672   30      Travel_Rarely        945                   Sales
# 1673  1673   32      Travel_Rarely       1303  Research & Development
# 1674  1674   29  Travel_Frequently       1184         Human Resources
# 1675  1675   36      Travel_Rarely        441                   Sales
# 1676  1676   36      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
df= df.drop('id',axis=1)

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  ...  StandardHours  StockOptionLevel  \
# 0                        4    Male  ...             80                 1
# 1                        1    Male  ...             80                 1
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1677.000000  1677.000000       1677.000000  1677.000000         1677.0
# mean     36.036971   892.749553          8.683959     2.937984            1.0
# std       8.507112   374.496259          7.826143     1.039078            0.0
# min      18.000000   107.000000          1.000000     1.000000            1.0
# 25%      30.000000   589.000000          2.000000     2.000000            1.0
# 50%      35.000000   890.000000          7.000000     3.000000            1.0
# 75%      41.000000  1223.000000         12.000000     4.000000            1.0
# max      60.000000  3921.000000         29.000000    15.000000            1.0
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1677.000000  1677.000000     1677.000000  1677.000000
# mean                  2.757901    67.798450        2.782349     1.998807
# ...

# %%
#Grouping and visualization

BusinessTravel = df.groupby("BusinessTravel")["BusinessTravel"].count()
BusinessTravel
# Out:
# BusinessTravel
# Non-Travel            126
# Travel_Frequently     261
# Travel_Rarely        1290
# Name: BusinessTravel, dtype: int64

# %%
BusinessTravel.plot(kind = 'bar', alpha = 0.7)
plt.legend(loc = 'upper right')

# %%
Department = df.groupby("Department")["Department"].count()
Department
# Out:
# Department
# Human Resources             39
# Research & Development    1167
# Sales                      471
# Name: Department, dtype: int64

# %%
Department.plot(kind = "bar", alpha = 0.7)
plt.legend(loc = "upper right")

# %%
EducationField = df.groupby("EducationField")["EducationField"].count()
EducationField
# Out:
# EducationField
# Human Resources      13
# Life Sciences       775
# Marketing           152
# Medical             549
# Other                82
# Technical Degree    106
# Name: EducationField, dtype: int64

# %%
EducationField.plot(alpha = 0.9, kind = 'bar')
plt.legend(loc = 'upper right')

# %%
Gender = df.groupby("Gender")["Gender"].count()
Gender
# Out:
# Gender
# Female     613
# Male      1064
# Name: Gender, dtype: int64

# %%
color = ["red", "blue"]
Gender.plot(alpha = 0.7, kind = "bar", color = color)
plt.legend(loc = "upper right")

# %%
JobRole = df.groupby("JobRole")["JobRole"].count()
JobRole
# Out:
# JobRole
# Healthcare Representative    155
# Human Resources               34
# Laboratory Technician        334
# Manager                      111
# Manufacturing Director       196
# Research Director             71
# Research Scientist           344
# Sales Executive              355
# Sales Representative          77
# Name: JobRole, dtype: int64

# %%
JobRole.plot(alpha = 0.7, kind = "bar")
plt.legend(loc = "upper right")

# %%
MaritalStatus = df.groupby('MaritalStatus')['MaritalStatus'].count()
MaritalStatus
# Out:
# MaritalStatus
# Divorced    327
# Married     773
# Single      577
# Name: MaritalStatus, dtype: int64

# %%
MaritalStatus.plot(alpha = 0.7, kind = "bar")
plt.legend(loc = "upper right")

# %%
OverTime = df.groupby("OverTime")["OverTime"].count()
OverTime
# Out:
# OverTime
# No     1277
# Yes     400
# Name: OverTime, dtype: int64

# %%
color = ["blue", "red"]
OverTime.plot(alpha = 0.4, kind = "bar", color = color)
plt.legend(loc = "upper right")

# %%
Age_DailyRate = df.groupby("Age")["DailyRate"].sum()

# %%
Age_DailyRate
# Out:
# Age
# 18    10663
# 19    11492
# 20     4491
# 21    13746
# 22    11549
# 23    14553
# 24    22606
# 25    31583
# 26    41974
# 27    59695
# 28    51948
# 29    83312
# 30    64783
# 31    75166
# 32    55527
# 33    47036
# 34    83960
# 35    74565
# 36    88349
# 37    48032
# 38    75136
# 39    51628
# 40    73770
# 41    36924
# 42    31195
# 43    26464
# 44    38017
# 45    36878
# 46    42812
# 47    19788
# 48    28305
# 49    16950
# 50    27006
# 51    14072
# 52    12563
# 53    17198
# 54     5301
# 55    16801
# 56     8095
# 57     3362
# 58     7964
# 59     9041
# 60     2841
# Name: DailyRate, dtype: int64

# %%
Age_DailyRate.plot(kind = "bar", alpha = 0.7, figsize = (20, 10))
# Out:
# <Axes: xlabel='Age'>

# %%
df = pd.get_dummies(df)

# %%
df.head(2)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   36        599                24          3              1
# 1   35        921                 8          3              1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4          42               3         1
# 1                        1          46               3         1
#
#    JobSatisfaction  ...  JobRole_Research Director  \
# 0                4  ...                          0
# 1                1  ...                          0
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                           0                        0
# 1                           0                        0
#
#    JobRole_Sales Representative  MaritalStatus_Divorced  \
# 0                             0                       0
# 1                             1                       0
#
#    MaritalStatus_Married  MaritalStatus_Single  Over18_Y  OverTime_No  \
# ...

# %%
df2 = pd.read_csv("/content/test.csv")

# %%
df2.head(4)
# Out:
#      id  Age BusinessTravel  DailyRate              Department  \
# 0  1677   19     Non-Travel        992  Research & Development
# 1  1678   45  Travel_Rarely       1136                   Sales
# 2  1679   37  Travel_Rarely        155  Research & Development
# 3  1680   32  Travel_Rarely        688  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        4  ...                        4             80
# 1                        3  ...                        3             80
# 2                        4  ...                        2             80
# ...

# %%
df2= df2.drop('id',axis=1)

# %%
df2
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      19         Non-Travel        992  Research & Development
# 1      45      Travel_Rarely       1136                   Sales
# 2      37      Travel_Rarely        155  Research & Development
# 3      32      Travel_Rarely        688  Research & Development
# 4      29  Travel_Frequently        464  Research & Development
# ...   ...                ...        ...                     ...
# 1114   31      Travel_Rarely        755                   Sales
# 1115   40      Travel_Rarely        654  Research & Development
# 1116   42  Travel_Frequently        884  Research & Development
# 1117   25  Travel_Frequently       1469                   Sales
# 1118   42      Travel_Rarely       1234  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                    1          1           Medical              1
# ...

# %%
test = pd.get_dummies(df2)

# %%
test.head(5)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   19        992                 1          1              1
# 1   45       1136                 4          4              1
# 2   37        155                13          3              1
# 3   32        688                 1          4              1
# 4   29        464                 9          1              1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4          43               3         1
# 1                        3          67               3         2
# 2                        4          41               3         1
# 3                        3          89               2         2
# 4                        3          79               3         1
#
#    JobSatisfaction  ...  JobRole_Research Director  \
# 0                3  ...                          0
# 1                1  ...                          0
# ...

# %%
X=df.drop("Attrition", axis=1)
y=df["Attrition"]

# %%
print(X)
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      36        599                24          3              1
# 1      35        921                 8          3              1
# 2      32        718                26          3              1
# 3      38       1488                 2          3              1
# 4      50       1017                 5          4              1
# ...   ...        ...               ...        ...            ...
# 1672   30        945                 1          3              1
# 1673   32       1303                 2          3              1
# 1674   29       1184                24          3              1
# 1675   36        441                 9          2              1
# 1676   36       1141                20          3              1
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                           4          42               3         1
# ...

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1672    0
# 1673    0
# 1674    1
# 1675    0
# 1676    0
# Name: Attrition, Length: 1677, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
test_size = 0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size, random_state = 20)

# %%
print("X_train shape {}, len {}.".format(X_train.shape,len(X_train)))
print("X_test shape {}, len {}.".format(X_test.shape,len(X_test)))
print("y_train shape {}, len {}.".format(y_train.shape,len(y_train)))
print("y_test shape {}, len {}.".format(y_test.shape,len(y_test)))
# Out:
# X_train shape (1257, 54), len 1257.
# X_test shape (420, 54), len 420.
# y_train shape (1257,), len 1257.
# y_test shape (420,), len 420.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 54 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1119 non-null   int64
#  1   DailyRate                          1119 non-null   int64
#  2   DistanceFromHome                   1119 non-null   int64
#  3   Education                          1119 non-null   int64
#  4   EmployeeCount                      1119 non-null   int64
#  5   EnvironmentSatisfaction            1119 non-null   int64
#  6   HourlyRate                         1119 non-null   int64
#  7   JobInvolvement                     1119 non-null   int64
#  8   JobLevel                           1119 non-null   int64
#  9   JobSatisfaction                    1119 non-null   int64
#  10  MonthlyIncome                      1119 non-null   int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1677 non-null   int64
#  1   DailyRate                          1677 non-null   int64
#  2   DistanceFromHome                   1677 non-null   int64
#  3   Education                          1677 non-null   int64
#  4   EmployeeCount                      1677 non-null   int64
#  5   EnvironmentSatisfaction            1677 non-null   int64
#  6   HourlyRate                         1677 non-null   int64
#  7   JobInvolvement                     1677 non-null   int64
#  8   JobLevel                           1677 non-null   int64
#  9   JobSatisfaction                    1677 non-null   int64
#  10  MonthlyIncome                      1677 non-null   int64
# ...

# %%
if any(test.select_dtypes(include='object').dtypes == 'object'):
    print("At least one column contains string values")
else:
    print("No column contains string values")
# Out:
# No column contains string values

# %%
if any(df.select_dtypes(include='object').dtypes == 'object'):
    print("At least one column contains string values")
else:
    print("No column contains string values")
# Out:
# No column contains string values

# %%
from sklearn.ensemble import RandomForestClassifier

r = RandomForestClassifier(n_estimators = 30, oob_score = True, max_features = 5, max_depth = 30)
r.fit(X, y)
y_pred = r.predict(test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score

# %%
r.score(X, y)
# Out:
# 0.9970184853905785
